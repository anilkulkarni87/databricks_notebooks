# %%
# %pip install great-expectations
# %pip install azure
# Out:
# Python interpreter will be restarted.
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=f1a91d874c9423f8a04d8f6324876d5d8ba868820b6f903b8f7709c751b60e68
#   Stored in directory: /root/.cache/pip/wheels/a0/16/9c/5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# Successfully built termcolor
# ...
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# ...
#     ERROR: Command errored out with exit status 1:
# ...

# %%
# %pip uninstall azure-storage-blob -y
# Out:
# Python interpreter will be restarted.
# Found existing installation: azure-storage-blob 1.5.0
# Uninstalling azure-storage-blob-1.5.0:
#   Successfully uninstalled azure-storage-blob-1.5.0
# Python interpreter will be restarted.

# %%
# %pip install azure-storage-blob
# Out:
# Python interpreter will be restarted.
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# azure 4.0.0 requires azure-storage-blob~=1.3, but you have azure-storage-blob 12.9.0 which is incompatible.
# ...
# Python interpreter will be restarted.

# %%
# %pip install sqlalchemy
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#Azure connection and storage container
AZURE_STORAGE_CONNECTION_STRING="DefaultEndpointsProtocol=https;AccountName=<account_name>;AccountKey=<account_key>;EndpointSuffix=core.windows.net"
#AZURE_STORAGE_CONNECTION_STRING = dbutils.secrets.get(scope="key-vault-secrets", key="gesuite-blob-storage-constring")
#STORAGE_CONTAINER=dbutils.secrets.get(scope="key-vault-secrets", key="gesuite-blob-storage-container")
STORAGE_CONTAINER="azure_storage_container_name"

# SMTP details for sending emails
SMTP_ADDRESS="SMTP_ADDRESS",
SMTP_PORT="SMTP_PORT",
SENDER_LOGIN="SENDER_LOGIN",
SENDER_PASSWORD="SENDER_PASSWORD",
SENDER_ALIAS="SENDER_ALIAS",
RECEIVER_EMAILS="RECEIVER_EMAILS"

# Postgres connection details - Metric Store
MS_USERNAME="username"
MS_PASSWORD="paaswrd"
MS_PORT="port"
MS_HOST="host"
MS_DATABASE="database"
MS_DRIVERNAME="postgresql"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
