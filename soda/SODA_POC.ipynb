# %% [markdown]
# #Implement Data Quality in Notebooks by using Soda
#
# 1. Install required dev tools
# 2. Install Libraries for
#   1. [Soda](https://www.soda.io/) -> Data quality framework
#   2. [GE](https://greatexpectations.io/) - Data quality framework
#   3. [Influxdb](https://www.influxdata.com/) - Time series database to publish and visualize measurements.
# 3. Read data from a sample csv and create Dataframe.
# 4. Create methods to return Soda scan results to Dataframe. (For easier analysis)
# 5. Define Soda scan yml and execute on Dataframe.
#   1. The results are also published to a free trial version of Soda Cloud.
# 6. Display the Scan results from the Dataframe.
#
# ##### TODO:
# 1. Explore GreatExpectations for Data quality
# 2. Explore publishing data to InfluxDB to replicate the dashboards in Soda Cloud.

# %%
# %run ./SODA_CLUSTER_SETUP
# Out:
# WARNING: You are using pip version 21.0.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/databricks/python3/bin/python -m pip install --upgrade pip' command.
# Collecting thrift
#   Downloading thrift-0.15.0.tar.gz (59 kB)
# Requirement already satisfied: six>=1.7.2 in /databricks/python3/lib/python3.8/site-packages (from thrift) (1.15.0)
# Building wheels for collected packages: thrift
#   Building wheel for thrift (setup.py): started
#   Building wheel for thrift (setup.py): finished with status 'done'
#   Created wheel for thrift: filename=thrift-0.15.0-cp38-cp38-linux_x86_64.whl size=399949 sha256=4dca8920eb8415562a34b7d3dae6727847c3e637cd9603bc395422249b81aff7
#   Stored in directory: /root/.cache/pip/wheels/4c/b5/5b/10af165d7e0895afdfe25ad487422ae8ada6ea422b0dc444ab
# Successfully built thrift
# Installing collected packages: thrift
# Successfully installed thrift-0.15.0
# WARNING: You are using pip version 21.0.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/databricks/python3/bin/python -m pip install --upgrade pip' command.
# ii  gcc                            4:9.3.0-1ubuntu2                  amd64        GNU C compiler
# ii  gcc-10-base:amd64              10.3.0-1ubuntu1~20.04             amd64        GCC, the GNU Compiler Collection (base package)
# ii  gcc-7-base:amd64               7.5.0-6ubuntu2                    amd64        GCC, the GNU Compiler Collection (base package)
# ii  gcc-8-base:amd64               8.4.0-3ubuntu2                    amd64        GCC, the GNU Compiler Collection (base package)
# ii  gcc-9                          9.3.0-17ubuntu1~20.04             amd64        GNU C compiler
# ii  gcc-9-base:amd64               9.3.0-17ubuntu1~20.04             amd64        GCC, the GNU Compiler Collection (base package)
# ii  libgcc-7-dev:amd64             7.5.0-6ubuntu2                    amd64        GCC support library (development files)
# ii  libgcc-9-dev:amd64             9.3.0-17ubuntu1~20.04             amd64        GCC support library (development files)
# ii  libgcc-s1:amd64                10.3.0-1ubuntu1~20.04             amd64        GCC support library
# Reading package lists...
# Building dependency tree...
# Reading state information...
# gcc is already the newest version (4:9.3.0-1ubuntu2).
# gcc set to manually installed.
# unixodbc-dev is already the newest version (2.3.6-0.1build1).
# The following additional packages will be installed:
#   python-is-python2
# The following packages will be REMOVED:
#   python-is-python3
# The following NEW packages will be installed:
#   libsasl2-dev python-dev-is-python2 python-is-python2
# 0 upgraded, 3 newly installed, 1 to remove and 21 not upgraded.
# Need to get 229 kB of archives.
# After this operation, 903 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 libsasl2-dev amd64 2.1.27+dfsg-2 [225 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 python-is-python2 all 2.7.17-4 [2,496 B]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 python-dev-is-python2 all 2.7.17-4 [1,396 B]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 229 kB in 1s (183 kB/s)
# (Reading database ...
# (Reading database ... 5%
# (Reading database ... 10%
# (Reading database ... 15%
# (Reading database ... 20%
# (Reading database ... 25%
# (Reading database ... 30%
# (Reading database ... 35%
# (Reading database ... 40%
# (Reading database ... 45%
# (Reading database ... 50%
# (Reading database ... 55%
# (Reading database ... 60%
# (Reading database ... 65%
# (Reading database ... 70%
# (Reading database ... 75%
# (Reading database ... 80%
# (Reading database ... 85%
# (Reading database ... 90%
# (Reading database ... 95%
# (Reading database ... 100%
# (Reading database ... 93055 files and directories currently installed.)
# Removing python-is-python3 (3.8.2-4) ...
# Selecting previously unselected package libsasl2-dev.
# (Reading database ...
# (Reading database ... 5%
# (Reading database ... 10%
# (Reading database ... 15%
# (Reading database ... 20%
# (Reading database ... 25%
# (Reading database ... 30%
# (Reading database ... 35%
# (Reading database ... 40%
# (Reading database ... 45%
# (Reading database ... 50%
# (Reading database ... 55%
# (Reading database ... 60%
# (Reading database ... 65%
# (Reading database ... 70%
# (Reading database ... 75%
# (Reading database ... 80%
# (Reading database ... 85%
# (Reading database ... 90%
# (Reading database ... 95%
# (Reading database ... 100%
# (Reading database ... 93051 files and directories currently installed.)
# Preparing to unpack .../libsasl2-dev_2.1.27+dfsg-2_amd64.deb ...
# Unpacking libsasl2-dev (2.1.27+dfsg-2) ...
# Selecting previously unselected package python-is-python2.
# Preparing to unpack .../python-is-python2_2.7.17-4_all.deb ...
# Unpacking python-is-python2 (2.7.17-4) ...
# Selecting previously unselected package python-dev-is-python2.
# Preparing to unpack .../python-dev-is-python2_2.7.17-4_all.deb ...
# Unpacking python-dev-is-python2 (2.7.17-4) ...
# Setting up libsasl2-dev (2.1.27+dfsg-2) ...
# Setting up python-is-python2 (2.7.17-4) ...
# Setting up python-dev-is-python2 (2.7.17-4) ...
# Processing triggers for man-db (2.9.1-1) ...
# Python interpreter will be restarted.
# Collecting soda-spark
#   Downloading soda_spark-0.3.1-py3-none-any.whl (10 kB)
# Collecting soda-sql-spark~=2.1
#   Downloading soda_sql_spark-2.1.3-py3-none-any.whl (4.7 kB)
# Collecting pyspark~=3.0
#   Downloading pyspark-3.2.1.tar.gz (281.4 MB)
# Collecting py4j==0.10.9.3
#   Downloading py4j-0.10.9.3-py2.py3-none-any.whl (198 kB)
# Collecting soda-sql-core==2.1.3
#   Downloading soda_sql_core-2.1.3-py3-none-any.whl (88 kB)
# Collecting thrift-sasl<1.0,>=0.4.3
#   Downloading thrift_sasl-0.4.3-py2.py3-none-any.whl (8.3 kB)
# Requirement already satisfied: thrift<1.0,>=0.13.0 in /databricks/python3/lib/python3.8/site-packages (from soda-sql-spark~=2.1->soda-spark) (0.15.0)
# Collecting sasl<1.0,>=0.3.1
#   Downloading sasl-0.3.1.tar.gz (44 kB)
# Collecting PyHive<1.0,>=0.6.3
#   Downloading PyHive-0.6.4.tar.gz (44 kB)
# Collecting pyodbc<5.0,>=4.0
#   Downloading pyodbc-4.0.32.tar.gz (280 kB)
# Collecting Deprecated<1.3,>=1.2.13
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests<3.0,>=2.23.0 in /databricks/python3/lib/python3.8/site-packages (from soda-sql-core==2.1.3->soda-sql-spark~=2.1->soda-spark) (2.25.1)
# Collecting pyyaml<6.0,>=5.4.1
#   Downloading PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662 kB)
# Requirement already satisfied: Jinja2<3.0,>=2.11.3 in /databricks/python3/lib/python3.8/site-packages (from soda-sql-core==2.1.3->soda-sql-spark~=2.1->soda-spark) (2.11.3)
# Collecting opentelemetry-exporter-otlp-proto-http<1.7,>=1.6.2
#   Downloading opentelemetry_exporter_otlp_proto_http-1.6.2-py3-none-any.whl (13 kB)
# Collecting click<9.0,>=8.0
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.13.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (84 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /databricks/python3/lib/python3.8/site-packages (from Jinja2<3.0,>=2.11.3->soda-sql-core==2.1.3->soda-sql-spark~=2.1->soda-spark) (1.1.1)
# Collecting googleapis-common-protos~=1.52
#   Downloading googleapis_common_protos-1.54.0-py2.py3-none-any.whl (207 kB)
# Collecting opentelemetry-sdk~=1.3
#   Downloading opentelemetry_sdk-1.9.1-py3-none-any.whl (64 kB)
# Collecting opentelemetry-proto==1.6.2
#   Downloading opentelemetry_proto-1.6.2-py3-none-any.whl (63 kB)
# Collecting backoff~=1.10.0
#   Downloading backoff-1.10.0-py2.py3-none-any.whl (31 kB)
# Collecting opentelemetry-api~=1.3
#   Downloading opentelemetry_api-1.9.1-py3-none-any.whl (47 kB)
# Requirement already satisfied: protobuf>=3.13.0 in /databricks/python3/lib/python3.8/site-packages (from opentelemetry-proto==1.6.2->opentelemetry-exporter-otlp-proto-http<1.7,>=1.6.2->soda-sql-core==2.1.3->soda-sql-spark~=2.1->soda-spark) (3.17.2)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.8/dist-packages (from opentelemetry-api~=1.3->opentelemetry-exporter-otlp-proto-http<1.7,>=1.6.2->soda-sql-core==2.1.3->soda-sql-spark~=2.1->soda-spark) (52.0.0)
# Collecting typing-extensions>=3.7.4
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Collecting opentelemetry-semantic-conventions==0.28b1
#   Downloading opentelemetry_semantic_conventions-0.28b1-py3-none-any.whl (23 kB)
# Requirement already satisfied: six>=1.9 in /databricks/python3/lib/python3.8/site-packages (from protobuf>=3.13.0->opentelemetry-proto==1.6.2->opentelemetry-exporter-otlp-proto-http<1.7,>=1.6.2->soda-sql-core==2.1.3->soda-sql-spark~=2.1->soda-spark) (1.15.0)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
# Requirement already satisfied: python-dateutil in /databricks/python3/lib/python3.8/site-packages (from PyHive<1.0,>=0.6.3->soda-sql-spark~=2.1->soda-spark) (2.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests<3.0,>=2.23.0->soda-sql-core==2.1.3->soda-sql-spark~=2.1->soda-spark) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /databricks/python3/lib/python3.8/site-packages (from requests<3.0,>=2.23.0->soda-sql-core==2.1.3->soda-sql-spark~=2.1->soda-spark) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.8/site-packages (from requests<3.0,>=2.23.0->soda-sql-core==2.1.3->soda-sql-spark~=2.1->soda-spark) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests<3.0,>=2.23.0->soda-sql-core==2.1.3->soda-sql-spark~=2.1->soda-spark) (2.10)
# Collecting pure-sasl>=0.6.2
#   Downloading pure-sasl-0.6.2.tar.gz (11 kB)
# Building wheels for collected packages: pyspark, PyHive, pyodbc, sasl, pure-sasl, future
#   Building wheel for pyspark (setup.py): started
#   Building wheel for pyspark (setup.py): finished with status 'done'
#   Created wheel for pyspark: filename=pyspark-3.2.1-py2.py3-none-any.whl size=281853646 sha256=b4842efe4dbe9c0e336c983e6b73ff97080546873652fbab129f993a22a05813
#   Stored in directory: /root/.cache/pip/wheels/58/94/83/915c9059e4b038e2d43a6058f307fe1c3e8536e5745f3b23b7
#   Building wheel for PyHive (setup.py): started
#   Building wheel for PyHive (setup.py): finished with status 'done'
#   Created wheel for PyHive: filename=PyHive-0.6.4-py3-none-any.whl size=51493 sha256=3bbff8ab2fda9b019a624def132ee4cdbc2744af73851f389ad4a6875ce92121
#   Stored in directory: /root/.cache/pip/wheels/84/f1/d7/6f7af9915dcb9abad04a80249755d01819315f77a3bbc976ba
#   Building wheel for pyodbc (setup.py): started
#   Building wheel for pyodbc (setup.py): finished with status 'done'
#   Created wheel for pyodbc: filename=pyodbc-4.0.32-cp38-cp38-linux_x86_64.whl size=359036 sha256=b0b73d3798780cbe25c92b33236ca7381e409893b3d0241664edaa859d789b7c
#   Stored in directory: /root/.cache/pip/wheels/68/de/de/65a129482924e96fb701c51488b907953acf25fe623bb177b3
#   Building wheel for sasl (setup.py): started
#   Building wheel for sasl (setup.py): finished with status 'done'
#   Created wheel for sasl: filename=sasl-0.3.1-cp38-cp38-linux_x86_64.whl size=292635 sha256=54cf16d6d6cb0448e1ef544a0ce8887990d403e6ff9373b1c34e61340df1c419
#   Stored in directory: /root/.cache/pip/wheels/f8/c1/d1/04c8916b295bc6adcbb6d423223d6f83e44ed356fd43659806
#   Building wheel for pure-sasl (setup.py): started
#   Building wheel for pure-sasl (setup.py): finished with status 'done'
#   Created wheel for pure-sasl: filename=pure_sasl-0.6.2-py3-none-any.whl size=11430 sha256=07eb20cd230740828c6b67af05730961b3adfb27c683d7d7337ba0eb8b47103e
#   Stored in directory: /root/.cache/pip/wheels/af/5e/ca/57ff2c5801d038e3d8b227a4fb492cd84e43a535d64a06f3f2
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=afcffc7ba77d72c1c53b838cb1db6881cf095db89d7ecaa787d88da4bb7ef4f7
#   Stored in directory: /root/.cache/pip/wheels/8e/70/28/3d6ccd6e315f65f245da085482a2e1c7d14b90b30f239e2cf4
# Successfully built pyspark PyHive pyodbc sasl pure-sasl future
# Installing collected packages: wrapt, Deprecated, typing-extensions, opentelemetry-semantic-conventions, opentelemetry-api, opentelemetry-sdk, opentelemetry-proto, googleapis-common-protos, backoff, pyyaml, pure-sasl, opentelemetry-exporter-otlp-proto-http, future, click, thrift-sasl, soda-sql-core, sasl, pyodbc, PyHive, py4j, soda-sql-spark, pyspark, soda-spark
# Successfully installed Deprecated-1.2.13 PyHive-0.6.4 backoff-1.10.0 click-8.0.3 future-0.18.2 googleapis-common-protos-1.54.0 opentelemetry-api-1.9.1 opentelemetry-exporter-otlp-proto-http-1.6.2 opentelemetry-proto-1.6.2 opentelemetry-sdk-1.9.1 opentelemetry-semantic-conventions-0.28b1 pure-sasl-0.6.2 py4j-0.10.9.3 pyodbc-4.0.32 pyspark-3.2.1 pyyaml-5.4.1 sasl-0.3.1 soda-spark-0.3.1 soda-sql-core-2.1.3 soda-sql-spark-2.1.3 thrift-sasl-0.4.3 typing-extensions-4.1.1 wrapt-1.13.3
# WARNING: You are using pip version 21.0.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-9e3dec8f-5174-4d6e-b256-b12af86f31ad/bin/python -m pip install --upgrade pip' command.
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Collecting influxdb-client
#   Downloading influxdb_client-1.25.0-py3-none-any.whl (525 kB)
# Collecting rx>=3.0.1
#   Downloading Rx-3.2.0-py3-none-any.whl (199 kB)
# Requirement already satisfied: urllib3>=1.15.1 in /databricks/python3/lib/python3.8/site-packages (from influxdb-client) (1.25.11)
# Requirement already satisfied: pytz>=2019.1 in /databricks/python3/lib/python3.8/site-packages (from influxdb-client) (2020.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /databricks/python3/lib/python3.8/site-packages (from influxdb-client) (2.8.1)
# Requirement already satisfied: certifi>=14.05.14 in /databricks/python3/lib/python3.8/site-packages (from influxdb-client) (2020.12.5)
# Requirement already satisfied: six>=1.10 in /databricks/python3/lib/python3.8/site-packages (from influxdb-client) (1.15.0)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.8/dist-packages (from influxdb-client) (52.0.0)
# Installing collected packages: rx, influxdb-client
# Successfully installed influxdb-client-1.25.0 rx-3.2.0
# WARNING: You are using pip version 21.0.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-9e3dec8f-5174-4d6e-b256-b12af86f31ad/bin/python -m pip install --upgrade pip' command.
# Python interpreter will be restarted.

# %%
# %run ./SODA_PROPERTIES

# %%
#Column names with a space caused the Soda scan to fail So i renamed the column names with space. 

from pyspark.sql.types import StructField, StructType, StringType,IntegerType
from pyspark.sql.functions import length

# File location and type
file_location = "/FileStore/tables/all_india_PO_list_without_APS_offices_ver2_lat_long.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
#df = spark.read.format(file_type).schema(custom_schema).option("header", first_row_is_header).option("sep", delimiter).load(file_location)

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

df = df.withColumnRenamed("Related Suboffice","RelatedSuboffice").withColumnRenamed("Related Headoffice","RelatedHeadoffice")


#df.where("Deliverystatus").show()
df = df.filter(df.Deliverystatus == "Delivery")

# %%
# Create a view or table

temp_table_name = "allindiapo"

df.createOrReplaceTempView(temp_table_name)

# %%
# %sql

/* Query the created temp table in a SQL cell */

select * from allindiapo
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>officename</th><th>pincode</th><th>officeType</th><th>Deliverystatus</th><th>divisionname</th><th>regionname</th><th>circlename</th><th>Taluk</th><th>Districtname</th><th>statename</th><th>Telephone</th><th>RelatedSuboffice</th><th>RelatedHeadoffice</th><th>longitude</th><th>latitude</th></tr></thead><tbody><tr><td>Achalapur B.O</td><td>504273</td><td>B.O</td><td>Delivery</td><td>Adilabad</td><td>Hyderabad</td><td>Andhra Pradesh</td><td>Asifabad</td><td>Adilabad</td><td>TELANGANA</td><td>NA</td><td>Rechini S.O</td><td>Mancherial H.O</td><td>NA</td><td>NA</td></tr><tr><td>Ada B.O</td><td>504293</td><td>B.O</td><td>Delivery</td><td>Adilabad</td><td>Hyderabad</td><td>Andhra Pradesh</td><td>Asifabad</td><td>Adilabad</td><td>TELANGANA</td><td>NA</td><td>Asifabad S.O</td><td>Mancherial H.O</td><td>NA</td><td>NA</td></tr><tr><td>Adegaon B.O</td><td>504307</td><td>B.O</td><td>Delivery</td><td>Adilabad</td><td>Hyderabad</td><td>Andhra Pradesh</td><td>Boath</td><td>Adilabad</td><td>TELANGANA</td><td>NA</td><td>Echoda S.O</td><td>Adilabad H.O</td><td>NA</td><td>NA</td></tr><tr><td>Adilabad H.O</td><td>504001</td><td>H.O</td><td>Delivery</td><td>Adilabad</td><td>Hyderabad</td><td>Andhra Pradesh</td><td>Adilabad</td><td>Adilabad</td><td>TELANGANA</td><td>08732-226738</td><td>NA</td><td>NA</td><td>NA</td><td>NA</td></tr><tr><td>Ainam B.O</td><td>504273</td><td>B.O</td><td>Delivery</td><td>Adilabad</td><td>Hyderabad</td><td>Andhra Pradesh</td><td>Asifabad</td><td>Adilabad</td><td>TELANGANA</td><td>NA</td><td>Rechini S.O</td><td>Mancherial H.O</td><td>NA</td><td>NA</td></tr><tr><td>Aknepalli B.O</td><td>504251</td><td>B.O</td><td>Delivery</td><td>Adilabad</td><td>Hyderabad</td><td>Andhra Pradesh</td><td>Luxettipet</td><td>Adilabad</td><td>TELANGANA</td><td>NA</td><td>Bellampalli S.O</td><td>Mancherial H.O</td><td>NA</td><td>NA</td></tr><tr><td>Akoli B.O</td><td>504309</td><td>B.O</td><td>Delivery</td><td>Adilabad</td><td>Hyderabad</td><td>Andhra Pradesh</td><td>Adilabad</td><td>Adilabad</td><td>TELANGANA</td><td>NA</td><td>Gumma S.O (Adilabad)</td><td>Adilabad H.O</td><td>NA</td><td>NA</td></tr><tr><td>Alegaon B.O</td><td>504201</td><td>B.O</td><td>Delivery</td><td>Adilabad</td><td>Hyderabad</td><td>Andhra Pradesh</td><td>Chennur</td><td>Adilabad</td><td>TELANGANA</td><td>NA</td><td>Chinnoor S.O</td><td>Mancherial H.O</td><td>NA</td><td>NA</td></tr><tr><td>Aloor B.O</td><td>504110</td><td>B.O</td><td>Delivery</td><td>Adilabad</td><td>Hyderabad</td><td>Andhra Pradesh</td><td>Nirmal</td><td>Adilabad</td><td>TELANGANA</td><td>NA</td><td>Chincholi (B) S.O</td><td>Adilabad H.O</td><td>NA</td><td>NA</td></tr><tr><td>Ambaripet B.O</td><td>504202</td><td>B.O</td><td>Delivery</td><td>Adilabad</td><td>Hyderabad</td><td>Andhra Pradesh</td><td>Khanapur</td><td>Adilabad</td><td>TELANGANA</td><td>NA</td><td>Peddur S.O</td><td>Adilabad H.O</td><td>NA</td><td>NA</td></tr><tr><td>Andavelli B.O</td><td>504296</td><td>B.O</td><td>Delivery</td><td>Adilabad</td><td>Hyderabad</td><td>Andhra Pradesh</td><td>Sirpur (t)</td><td>Adilabad</td><td>TELANGANA</td><td>NA</td><td>Sirpur Khagaznagar S.O</td><td>Mancherial H.O</td><td>NA</td><td>NA</td></tr><tr><td>Andugulpet B.O</td><td>504231</td><td>B.O</td><td>Delivery</td><td>Adilabad</td><td>Hyderabad</td><td>Andhra Pradesh</td><td>Luxettipet</td><td>Adilabad</td><td>TELANGANA</td><td>NA</td><td>Kalyani Khani S.O</td><td>Mancherial H.O</td><td>NA</td><td>NA</td></tr><tr><td>Andukur B.O</td><td>504109</td><td>B.O</td><td>Delivery</td><td>Adilabad</td><td>Hyderabad</td><td>Andhra Pradesh</td><td>Nirmal</td><td>Adilabad</td><td>TELANGANA</td><td>NA</td><td>Kuntala S.O</td><td>Adilabad H.O</td><td>NA</td><td>NA</td></tr><tr><td>Angarajpally B.O</td><td>504201</td><td>B.O</td><td>Delivery</td><td>Adilabad</td><td>Hyderabad</td><td>Andhra Pradesh</td><td>Chennur</td><td>Adilabad</td><td>TELANGANA</td><td>NA</ ...

# %%
from pyspark.sql import DataFrame, SparkSession
from sodaspark import scan
import pyodbc

#Enable connection to Soda Cloud
import os
from sodasql.soda_server_client.soda_server_client import SodaServerClient
soda_server_client = SodaServerClient(
  host=SODA_HOST,
  api_key_id=SODA_API_KEY_ID,
  api_key_secret =SODA_API_KEY_SECRET
    )
#Define the soda scan yml file
#Lot of documentation available at https://docs.soda.io/soda-sql/sql_metrics.html#metric-groups-and-dependencies
scan_definition = (
  """
    table_name: podata
    metrics:
    - row_count
    - max_length
    - unique_count
    - distinct
    - duplicate_count
    metric_groups:
    - length
    - profiling
    samples:
      table_limit: 50
    tests:
    - row_count > 0
    columns:
      Deliverystatus:
        tests:
        - distinct == 2
      divisionname:
        tests:
        - maxs
    sql_metrics:
    - sql: SELECT statename, count(pincode) as total_pincode FROM podata GROUP BY statename
      group_fields:
      - statename
      tests:
      - total_pincode > 20
    - sql: SELECT count(statename) as telangana_count FROM podata WHERE statename = 'TELANGANA'
      tests:
      - telangana_count > 30
    """
)

# %%
#Execute the scan based on tests defined
scan_result = scan.execute(scan_definition, df, soda_server_client=soda_server_client, as_frames=True)
measurements_df = scan_result[0]
testResults_df = scan_result[1]
errors_df = scan_result[2]
# Out:
# Soda Cloud error: Could not start scan: HTTPSConnectionPool(host="('cloud.soda.io',)", port=443): Max retries exceeded with url: /api/command (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f0b43954df0>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Skipping subsequent Soda Cloud communication but continuing the scan

# %%
#Convert them to Dataframe and maybe persist in adatabase for visualization.
#If you have signed up for Soda Cloud - That takes care of visualization/alerts and incidents.
display(measurements_df)
display(testResults_df)
display(testResults_df.select("test.*", "passed","skipped","values","error"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>metric</th><th>column_name</th><th>value</th><th>group_values</th></tr></thead><tbody><tr><td>schema</td><td>null</td><td>[{logicalType=text, nullable=true, semanticType=text, dataType=string, name=officename, type=string}, {logicalType=number, nullable=true, semanticType=number, dataType=int, name=pincode, type=int}, {logicalType=text, nullable=true, semanticType=text, dataType=string, name=officeType, type=string}, {logicalType=text, nullable=true, semanticType=text, dataType=string, name=Deliverystatus, type=string}, {logicalType=text, nullable=true, semanticType=text, dataType=string, name=divisionname, type=string}, {logicalType=text, nullable=true, semanticType=text, dataType=string, name=regionname, type=string}, {logicalType=text, nullable=true, semanticType=text, dataType=string, name=circlename, type=string}, {logicalType=text, nullable=true, semanticType=text, dataType=string, name=Taluk, type=string}, {logicalType=text, nullable=true, semanticType=text, dataType=string, name=Districtname, type=string}, {logicalType=text, nullable=true, semanticType=text, dataType=string, name=statename, type=string}, {logicalType=text, nullable=true, semanticType=text, dataType=string, name=Telephone, type=string}, {logicalType=text, nullable=true, semanticType=text, dataType=string, name=RelatedSuboffice, type=string}, {logicalType=text, nullable=true, semanticType=text, dataType=string, name=RelatedHeadoffice, type=string}, {logicalType=text, nullable=true, semanticType=text, dataType=string, name=longitude, type=string}, {logicalType=text, nullable=true, semanticType=text, dataType=string, name=latitude, type=string}]</td><td>null</td></tr><tr><td>row_count</td><td>null</td><td>145298</td><td>null</td></tr><tr><td>values_count</td><td>officename</td><td>145298</td><td>null</td></tr><tr><td>valid_count</td><td>officename</td><td>145298</td><td>null</td></tr><tr><td>avg_length</td><td>officename</td><td>13.189961320871587</td><td>null</td></tr><tr><td>min_length</td><td>officename</td><td>5</td><td>null</td></tr><tr><td>max_length</td><td>officename</td><td>50</td><td>null</td></tr><tr><td>values_count</td><td>pincode</td><td>145298</td><td>null</td></tr><tr><td>valid_count</td><td>pincode</td><td>145298</td><td>null</td></tr><tr><td>min</td><td>pincode</td><td>110001</td><td>null</td></tr><tr><td>max</td><td>pincode</td><td>855117</td><td>null</td></tr><tr><td>values_count</td><td>officeType</td><td>145298</td><td>null</td></tr><tr><td>valid_count</td><td>officeType</td><td>145298</td><td>null</td></tr><tr><td>avg_length</td><td>officeType</td><td>3.6529683822213657</td><td>null</td></tr><tr><td>min_length</td><td>officeType</td><td>3</td><td>null</td></tr><tr><td>max_length</td><td>officeType</td><td>28</td><td>null</td></tr><tr><td>values_count</td><td>Deliverystatus</td><td>145298</td><td>null</td></tr><tr><td>valid_count</td><td>Deliverystatus</td><td>145298</td><td>null</td></tr><tr><td>avg_length</td><td>Deliverystatus</td><td>8.0</td><td>null</td></tr><tr><td>min_length</td><td>Deliverystatus</td><td>8</td><td>null</td></tr><tr><td>max_length</td><td>Deliverystatus</td><td>8</td><td>null</td></tr><tr><td>values_count</td><td>divisionname</td><td>145298</td><td>null</td></tr><tr><td>valid_count</td><td>divisionname</td><td>145298</td><td>null</td></tr><tr><td>avg_length</td><td>divisionname</td><td>8.426750540268964</td><td>null</td></tr><tr><td>min_length</td><td>divisionname</td><td>3</td><td>null</td></tr><tr><td>max_length</td><td>divisionname</td><td>23</td><td>null</td></tr><tr><td>values_count</td><td>regionname</td><td>145298</td><td>null</td></tr><tr><td>valid_count</td><td>regionname</td><td>145298</td><td>null</td></tr><tr><td>avg_length</td><td>regionname</td><td>9.430322509600957</td><td>null</td></tr><tr><td>min_length</td><td>regionname</td><td>4</td><td>null</td></tr><tr><td>max_length</td>< ...
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>test</th><th>passed</th><th>skipped</th><th>values</th><th>error</th><th>group_values</th></tr></thead><tbody><tr><td>List({"sql_metric_index":0,"expression":"total_pincode > 20"}, sqlmetric(0) test(total_pincode > 20), total_pincode > 20, List(total_pincode), null, soda-sql)</td><td>true</td><td>false</td><td>Map(expression_result -> 3060, total_pincode -> 3060)</td><td>null</td><td>Map(statename -> CHATTISGARH)</td></tr><tr><td>List({"sql_metric_index":0,"expression":"total_pincode > 20"}, sqlmetric(0) test(total_pincode > 20), total_pincode > 20, List(total_pincode), null, soda-sql)</td><td>true</td><td>false</td><td>Map(expression_result -> 8802, total_pincode -> 8802)</td><td>null</td><td>Map(statename -> BIHAR)</td></tr><tr><td>List({"sql_metric_index":0,"expression":"total_pincode > 20"}, sqlmetric(0) test(total_pincode > 20), total_pincode > 20, List(total_pincode), null, soda-sql)</td><td>true</td><td>false</td><td>Map(expression_result -> 76, total_pincode -> 76)</td><td>null</td><td>Map(statename -> PONDICHERRY)</td></tr><tr><td>List({"sql_metric_index":0,"expression":"total_pincode > 20"}, sqlmetric(0) test(total_pincode > 20), total_pincode > 20, List(total_pincode), null, soda-sql)</td><td>true</td><td>false</td><td>Map(expression_result -> 5555, total_pincode -> 5555)</td><td>null</td><td>Map(statename -> TELANGANA)</td></tr><tr><td>List({"sql_metric_index":0,"expression":"total_pincode > 20"}, sqlmetric(0) test(total_pincode > 20), total_pincode > 20, List(total_pincode), null, soda-sql)</td><td>true</td><td>false</td><td>Map(expression_result -> 9872, total_pincode -> 9872)</td><td>null</td><td>Map(statename -> ANDHRA PRADESH)</td></tr><tr><td>List({"sql_metric_index":0,"expression":"total_pincode > 20"}, sqlmetric(0) test(total_pincode > 20), total_pincode > 20, List(total_pincode), null, soda-sql)</td><td>true</td><td>false</td><td>Map(expression_result -> 3729, total_pincode -> 3729)</td><td>null</td><td>Map(statename -> ASSAM)</td></tr><tr><td>List({"sql_metric_index":0,"expression":"total_pincode > 20"}, sqlmetric(0) test(total_pincode > 20), total_pincode > 20, List(total_pincode), null, soda-sql)</td><td>false</td><td>false</td><td>Map(expression_result -> 9, total_pincode -> 9)</td><td>null</td><td>Map(statename -> NULL)</td></tr><tr><td>List({"sql_metric_index":0,"expression":"total_pincode > 20"}, sqlmetric(0) test(total_pincode > 20), total_pincode > 20, List(total_pincode), null, soda-sql)</td><td>false</td><td>false</td><td>Map(expression_result -> 19, total_pincode -> 19)</td><td>null</td><td>Map(statename -> DAMAN & DIU)</td></tr><tr><td>List({"sql_metric_index":0,"expression":"total_pincode > 20"}, sqlmetric(0) test(total_pincode > 20), total_pincode > 20, List(total_pincode), null, soda-sql)</td><td>true</td><td>false</td><td>Map(expression_result -> 162, total_pincode -> 162)</td><td>null</td><td>Map(statename -> DELHI)</td></tr><tr><td>List({"sql_metric_index":0,"expression":"total_pincode > 20"}, sqlmetric(0) test(total_pincode > 20), total_pincode > 20, List(total_pincode), null, soda-sql)</td><td>true</td><td>false</td><td>Map(expression_result -> 2737, total_pincode -> 2737)</td><td>null</td><td>Map(statename -> HIMACHAL PRADESH)</td></tr><tr><td>List({"sql_metric_index":0,"expression":"total_pincode > 20"}, sqlmetric(0) test(total_pincode > 20), total_pincode > 20, List(total_pincode), null, soda-sql)</td><td>true</td><td>false</td><td>Map(expression_result -> 8539, total_pincode -> 8539)</td><td>null</td><td>Map(statename -> GUJARAT)</td></tr><tr><td>List({"sql_metric_index":0,"expression":"total_pincode > 20"}, sqlmetric(0) test(total_pincode > 20), total_pincode > 20, List(total_pincode), null, soda-sql)</td><td>true</td><td>false</td><td>Map(expression_result -> 9171, total_pincode -> 9171)</td><td>null</td><td>Map(statename -> KARNATAKA)</td></tr><tr><td>List({"sql ...
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>title</th><th>expression</th><th>metrics</th><th>column</th><th>source</th><th>passed</th><th>skipped</th><th>values</th><th>error</th></tr></thead><tbody><tr><td>{"sql_metric_index":0,"expression":"total_pincode > 20"}</td><td>sqlmetric(0) test(total_pincode > 20)</td><td>total_pincode > 20</td><td>List(total_pincode)</td><td>null</td><td>soda-sql</td><td>true</td><td>false</td><td>Map(expression_result -> 3060, total_pincode -> 3060)</td><td>null</td></tr><tr><td>{"sql_metric_index":0,"expression":"total_pincode > 20"}</td><td>sqlmetric(0) test(total_pincode > 20)</td><td>total_pincode > 20</td><td>List(total_pincode)</td><td>null</td><td>soda-sql</td><td>true</td><td>false</td><td>Map(expression_result -> 8802, total_pincode -> 8802)</td><td>null</td></tr><tr><td>{"sql_metric_index":0,"expression":"total_pincode > 20"}</td><td>sqlmetric(0) test(total_pincode > 20)</td><td>total_pincode > 20</td><td>List(total_pincode)</td><td>null</td><td>soda-sql</td><td>true</td><td>false</td><td>Map(expression_result -> 76, total_pincode -> 76)</td><td>null</td></tr><tr><td>{"sql_metric_index":0,"expression":"total_pincode > 20"}</td><td>sqlmetric(0) test(total_pincode > 20)</td><td>total_pincode > 20</td><td>List(total_pincode)</td><td>null</td><td>soda-sql</td><td>true</td><td>false</td><td>Map(expression_result -> 5555, total_pincode -> 5555)</td><td>null</td></tr><tr><td>{"sql_metric_index":0,"expression":"total_pincode > 20"}</td><td>sqlmetric(0) test(total_pincode > 20)</td><td>total_pincode > 20</td><td>List(total_pincode)</td><td>null</td><td>soda-sql</td><td>true</td><td>false</td><td>Map(expression_result -> 9872, total_pincode -> 9872)</td><td>null</td></tr><tr><td>{"sql_metric_index":0,"expression":"total_pincode > 20"}</td><td>sqlmetric(0) test(total_pincode > 20)</td><td>total_pincode > 20</td><td>List(total_pincode)</td><td>null</td><td>soda-sql</td><td>true</td><td>false</td><td>Map(expression_result -> 3729, total_pincode -> 3729)</td><td>null</td></tr><tr><td>{"sql_metric_index":0,"expression":"total_pincode > 20"}</td><td>sqlmetric(0) test(total_pincode > 20)</td><td>total_pincode > 20</td><td>List(total_pincode)</td><td>null</td><td>soda-sql</td><td>false</td><td>false</td><td>Map(expression_result -> 9, total_pincode -> 9)</td><td>null</td></tr><tr><td>{"sql_metric_index":0,"expression":"total_pincode > 20"}</td><td>sqlmetric(0) test(total_pincode > 20)</td><td>total_pincode > 20</td><td>List(total_pincode)</td><td>null</td><td>soda-sql</td><td>false</td><td>false</td><td>Map(expression_result -> 19, total_pincode -> 19)</td><td>null</td></tr><tr><td>{"sql_metric_index":0,"expression":"total_pincode > 20"}</td><td>sqlmetric(0) test(total_pincode > 20)</td><td>total_pincode > 20</td><td>List(total_pincode)</td><td>null</td><td>soda-sql</td><td>true</td><td>false</td><td>Map(expression_result -> 162, total_pincode -> 162)</td><td>null</td></tr><tr><td>{"sql_metric_index":0,"expression":"total_pincode > 20"}</td><td>sqlmetric(0) test(total_pincode > 20)</td><td>total_pincode > 20</td><td>List(total_pincode)</td><td>null</td><td>soda-sql</td><td>true</td><td>false</td><td>Map(expression_result -> 2737, total_pincode -> 2737)</td><td>null</td></tr><tr><td>{"sql_metric_index":0,"expression":"total_pincode > 20"}</td><td>sqlmetric(0) test(total_pincode > 20)</td><td>total_pincode > 20</td><td>List(total_pincode)</td><td>null</td><td>soda-sql</td><td>true</td><td>false</td><td>Map(expression_result -> 8539, total_pincode -> 8539)</td><td>null</td></tr><tr><td>{"sql_metric_index":0,"expression":"total_pincode > 20"}</td><td>sqlmetric(0) test(total_pincode > 20)</td><td>total_pincode > 20</td><td>List(total_pincode)</td><td>null</td><td>soda-sql</td><td>true</td><td>false</td><td>Map(expression_result -> 9171, total_pincode -> 9171)</td><td>null</td></tr><tr><td>{"sql_metric_index":0,"expression":"t ...

# %%
from datetime import datetime
import influxdb_client
from influxdb_client import InfluxDBClient, Point, WritePrecision
from influxdb_client.client.write_api import SYNCHRONOUS

# You can generate an API token from the "API Tokens Tab" in the UI
token = INFLUX_TOKEN
org = INFLUX_ORG
bucket = INFLUX_BUCKET
url= INFLUX_URL


soda_measurements = scan_result[0].filter(scan_result[0].metric == "unique_count")
display(soda_measurements)

client = influxdb_client.InfluxDBClient(
    url=url,
    token=token,
    org=org
)

write_api = client.write_api(write_options=SYNCHRONOUS)

# soda_measurements = scan_result[0].collect()
for row in soda_measurements.collect():
  p = influxdb_client.Point(row["metric"]).tag("column_name", row["column_name"]).field("value", int(row["value"]))
  write_api.write(bucket=bucket, org=org, record=p)

client.close()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>metric</th><th>column_name</th><th>value</th><th>group_values</th></tr></thead><tbody><tr><td>unique_count</td><td>officename</td><td>110893</td><td>null</td></tr><tr><td>unique_count</td><td>pincode</td><td>3332</td><td>null</td></tr><tr><td>unique_count</td><td>officeType</td><td>0</td><td>null</td></tr><tr><td>unique_count</td><td>Deliverystatus</td><td>0</td><td>null</td></tr><tr><td>unique_count</td><td>divisionname</td><td>13</td><td>null</td></tr><tr><td>unique_count</td><td>regionname</td><td>0</td><td>null</td></tr><tr><td>unique_count</td><td>circlename</td><td>0</td><td>null</td></tr><tr><td>unique_count</td><td>Taluk</td><td>3682</td><td>null</td></tr><tr><td>unique_count</td><td>Districtname</td><td>4</td><td>null</td></tr><tr><td>unique_count</td><td>statename</td><td>0</td><td>null</td></tr><tr><td>unique_count</td><td>Telephone</td><td>15925</td><td>null</td></tr><tr><td>unique_count</td><td>RelatedSuboffice</td><td>1168</td><td>null</td></tr><tr><td>unique_count</td><td>RelatedHeadoffice</td><td>1</td><td>null</td></tr><tr><td>unique_count</td><td>longitude</td><td>105</td><td>null</td></tr><tr><td>unique_count</td><td>latitude</td><td>101</td><td>null</td></tr></tbody></table></div>
